# %% [markdown]
# <a href="https://www.kaggle.com/code/mirhussainali/gender-classify-data?scriptVersionId=188121452" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

#For  confusion matrixes
from sklearn.metrics import confusion_matrix

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
print(os.listdir("../input/voicegender"))

     

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# ['voice.csv']

# %% [markdown]
# #Read our data from dataset.
# data=pd.read_csv("/kaggle/input/voicegender")

# %%
data=pd.read_csv('/kaggle/input/voicegender/voice.csv')

# %%
data.head()
# Out:
#    meanfreq        sd    median       Q25       Q75       IQR       skew  \
# 0  0.059781  0.064241  0.032027  0.015071  0.090193  0.075122  12.863462
# 1  0.066009  0.067310  0.040229  0.019414  0.092666  0.073252  22.423285
# 2  0.077316  0.083829  0.036718  0.008701  0.131908  0.123207  30.757155
# 3  0.151228  0.072111  0.158011  0.096582  0.207955  0.111374   1.232831
# 4  0.135120  0.079146  0.124656  0.078720  0.206045  0.127325   1.101174
#
#           kurt    sp.ent       sfm  ...  centroid   meanfun    minfun  \
# 0   274.402906  0.893369  0.491918  ...  0.059781  0.084279  0.015702
# 1   634.613855  0.892193  0.513724  ...  0.066009  0.107937  0.015826
# 2  1024.927705  0.846389  0.478905  ...  0.077316  0.098706  0.015656
# 3     4.177296  0.963322  0.727232  ...  0.151228  0.088965  0.017798
# 4     4.333713  0.971955  0.783568  ...  0.135120  0.106398  0.016931
#
#      maxfun   meandom    mindom    maxdom   dfrange   modindx  label
# ...

# %%
data.describe()
# Out:
#           meanfreq           sd       median          Q25          Q75  \
# count  3168.000000  3168.000000  3168.000000  3168.000000  3168.000000
# mean      0.180907     0.057126     0.185621     0.140456     0.224765
# std       0.029918     0.016652     0.036360     0.048680     0.023639
# min       0.039363     0.018363     0.010975     0.000229     0.042946
# 25%       0.163662     0.041954     0.169593     0.111087     0.208747
# 50%       0.184838     0.059155     0.190032     0.140286     0.225684
# 75%       0.199146     0.067020     0.210618     0.175939     0.243660
# max       0.251124     0.115273     0.261224     0.247347     0.273469
#
#                IQR         skew         kurt       sp.ent          sfm  \
# count  3168.000000  3168.000000  3168.000000  3168.000000  3168.000000
# mean      0.084309     3.140168    36.568461     0.895127     0.408216
# std       0.042783     4.240529   134.928661     0.044980     0.177521
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3168 entries, 0 to 3167
# Data columns (total 21 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   meanfreq  3168 non-null   float64
#  1   sd        3168 non-null   float64
#  2   median    3168 non-null   float64
#  3   Q25       3168 non-null   float64
#  4   Q75       3168 non-null   float64
#  5   IQR       3168 non-null   float64
#  6   skew      3168 non-null   float64
#  7   kurt      3168 non-null   float64
#  8   sp.ent    3168 non-null   float64
#  9   sfm       3168 non-null   float64
#  10  mode      3168 non-null   float64
#  11  centroid  3168 non-null   float64
#  12  meanfun   3168 non-null   float64
#  13  minfun    3168 non-null   float64
#  14  maxfun    3168 non-null   float64
#  15  meandom   3168 non-null   float64
#  16  mindom    3168 non-null   float64
#  17  maxdom    3168 non-null   float64
#  18  dfrange   3168 non-null   float64
# ...

# %%
data1=data.drop(['label'],axis=1)

# %%
data1.info
# Out:
# <bound method DataFrame.info of       meanfreq        sd    median       Q25       Q75       IQR       skew  \
# 0     0.059781  0.064241  0.032027  0.015071  0.090193  0.075122  12.863462
# 1     0.066009  0.067310  0.040229  0.019414  0.092666  0.073252  22.423285
# 2     0.077316  0.083829  0.036718  0.008701  0.131908  0.123207  30.757155
# 3     0.151228  0.072111  0.158011  0.096582  0.207955  0.111374   1.232831
# 4     0.135120  0.079146  0.124656  0.078720  0.206045  0.127325   1.101174
# ...        ...       ...       ...       ...       ...       ...        ...
# 3163  0.131884  0.084734  0.153707  0.049285  0.201144  0.151859   1.762129
# 3164  0.116221  0.089221  0.076758  0.042718  0.204911  0.162193   0.693730
# 3165  0.142056  0.095798  0.183731  0.033424  0.224360  0.190936   1.876502
# 3166  0.143659  0.090628  0.184976  0.043508  0.219943  0.176435   1.591065
# 3167  0.165509  0.092884  0.183044  0.070072  0.250827  0.180756   1.705029
#
# ...

# %%
data1.corr()
# Out:
#           meanfreq        sd    median       Q25       Q75       IQR  \
# meanfreq  1.000000 -0.739039  0.925445  0.911416  0.740997 -0.627605
# sd       -0.739039  1.000000 -0.562603 -0.846931 -0.161076  0.874660
# median    0.925445 -0.562603  1.000000  0.774922  0.731849 -0.477352
# Q25       0.911416 -0.846931  0.774922  1.000000  0.477140 -0.874189
# Q75       0.740997 -0.161076  0.731849  0.477140  1.000000  0.009636
# IQR      -0.627605  0.874660 -0.477352 -0.874189  0.009636  1.000000
# skew     -0.322327  0.314597 -0.257407 -0.319475 -0.206339  0.249497
# kurt     -0.316036  0.346241 -0.243382 -0.350182 -0.148881  0.316185
# sp.ent   -0.601203  0.716620 -0.502005 -0.648126 -0.174905  0.640813
# sfm      -0.784332  0.838086 -0.661690 -0.766875 -0.378198  0.663601
# mode      0.687715 -0.529150  0.677433  0.591277  0.486857 -0.403764
# centroid  1.000000 -0.739039  0.925445  0.911416  0.740997 -0.627605
# meanfun   0.460844 -0.466281  0.414909  0.545035  0.155091 -0.534462
# ...

# %%
data.label=[1 if each=="female" else 0 for each in data.label]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3168 entries, 0 to 3167
# Data columns (total 21 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   meanfreq  3168 non-null   float64
#  1   sd        3168 non-null   float64
#  2   median    3168 non-null   float64
#  3   Q25       3168 non-null   float64
#  4   Q75       3168 non-null   float64
#  5   IQR       3168 non-null   float64
#  6   skew      3168 non-null   float64
#  7   kurt      3168 non-null   float64
#  8   sp.ent    3168 non-null   float64
#  9   sfm       3168 non-null   float64
#  10  mode      3168 non-null   float64
#  11  centroid  3168 non-null   float64
#  12  meanfun   3168 non-null   float64
#  13  minfun    3168 non-null   float64
#  14  maxfun    3168 non-null   float64
#  15  meandom   3168 non-null   float64
#  16  mindom    3168 non-null   float64
#  17  maxdom    3168 non-null   float64
#  18  dfrange   3168 non-null   float64
# ...

# %%
y=data.label.values
x_data=data.drop(['label'],axis=1)

# %%
x=(x_data-np.min(x_data)) / (np.max(x_data.values))

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

method_names=[]
method_scores=[]

# %%
from sklearn.linear_model import LogisticRegression
log_reg=LogisticRegression()
log_reg.fit(x_train,y_train)
print("Logistic Regression classification Testbaccuracy {}".format(log_reg.score(x_test,y_test)))
method_names.append("Logistic Reg.")
method_scores.append(log_reg.score(x_test,y_test))



y_pred=log_reg.predict(x_test)
conf_mat=confusion_matrix(y_test,y_pred)


f,ax=plt.subplots(figsize=(5,5))
sns.heatmap(conf_mat,annot=True,linewidth=0.5,linecolor="red",fmt=".0f",ax=ax)
plt.xlabel("Predicted values")
plt.ylabel("True values")
plt.show()
# Out:
# Logistic Regression classification Testbaccuracy 0.49053627760252366

# %%
from sklearn.tree import DecisionTreeClassifier
dtree=DecisionTreeClassifier()
dtree.fit(x_train,y_train)
print("DecisionTreeClassifier Testbaccuracy {}".format(dtree.score(x_test,y_test)))
method_names.append("Decison Tree.")
method_scores.append(dtree.score(x_test,y_test))



y_pred=dtree.predict(x_test)
conf_mat=confusion_matrix(y_test,y_pred)


f,ax=plt.subplots(figsize=(5,5))
sns.heatmap(conf_mat,annot=True,linewidth=0.5,linecolor="red",fmt=".0f",ax=ax)
plt.xlabel("Predicted values")
plt.ylabel("True values")
plt.show()
# Out:
# DecisionTreeClassifier Testbaccuracy 0.9637223974763407

# %%
from sklearn.neighbors import KNeighborsClassifier 
knn=KNeighborsClassifier()
knn.fit(x_train,y_train)
print("KNeighborsClassifier  Testbaccuracy {}".format(dtree.score(x_test,y_test)))
method_names.append("KNeighborsClassifier .")
method_scores.append(knn.score(x_test,y_test))



y_pred=knn.predict(x_test)
conf_mat=confusion_matrix(y_test,y_pred)


f,ax=plt.subplots(figsize=(5,5))
sns.heatmap(conf_mat,annot=True,linewidth=0.5,linecolor="red",fmt=".0f",ax=ax)
plt.xlabel("Predicted values")
plt.ylabel("True values")
plt.show()
# Out:
# KNeighborsClassifier  Testbaccuracy 0.9637223974763407

# %%
from sklearn.svm import SVC
svm=SVC(random_state=42)
svm.fit(x_train,y_train)
print("SVM Classification Testbaccuracy {}".format(svm.score(x_test,y_test)))
method_names.append("SVM .")
method_scores.append(svm.score(x_test,y_test))



y_pred=svm.predict(x_test)
conf_mat=confusion_matrix(y_test,y_pred)


f,ax=plt.subplots(figsize=(5,5))
sns.heatmap(conf_mat,annot=True,linewidth=0.5,linecolor="red",fmt=".0f",ax=ax)
plt.xlabel("Predicted values")
plt.ylabel("True values")
plt.show()
# Out:
# SVM Classification Testbaccuracy 0.6561514195583596

# %%
from sklearn.ensemble import RandomForestClassifier
rand_forest=RandomForestClassifier(n_estimators=100,random_state=42)
rand_forest.fit(x_train,y_train)
print("RandomForestClassification Testbaccuracy {}".format(rand_forest.score(x_test,y_test)))
method_names.append("RandomForestClassification .")
method_scores.append(rand_forest.score(x_test,y_test))



y_pred=rand_forest.predict(x_test)
conf_mat=confusion_matrix(y_test,y_pred)


f,ax=plt.subplots(figsize=(5,5))
sns.heatmap(conf_mat,annot=True,linewidth=0.5,linecolor="red",fmt=".0f",ax=ax)
plt.xlabel("Predicted values")
plt.ylabel("True values")
plt.show()
# Out:
# RandomForestClassification Testbaccuracy 0.9810725552050473

# %%
from sklearn.ensemble import GradientBoostingClassifier

gbc=GradientBoostingClassifier(n_estimators=500,learning_rate=0.05,random_state=100,max_features=5)


gbc.fit(x_train,y_train)
print("Gradient Forest Classification Score: ",gbc.score(x_test,y_test))
method_names.append("Gradient Forest")
method_scores.append(gbc.score(x_test,y_test))


y_pred=gbc.predict(x_test)
conf_mat=confusion_matrix(y_test,y_pred)


f,ax=plt.subplots(figsize=(5,5))
sns.heatmap(conf_mat,annot=True,linewidth=0.5,linecolor="red",fmt=".0f",ax=ax)
plt.xlabel("Predicted values")
plt.ylabel("True values")
plt.show()
# Out:
# Gradient Forest Classification Score:  0.9842271293375394

# %%
from sklearn.model_selection import GridSearchCV 
grid={
    'learning_rate':[0.01,0.05,0.1],
    'n_estimators':np.arange(100,500,100),
    #'criterion':[]
}
gb=GradientBoostingClassifier()
gb_cv=GridSearchCV(gb,grid,cv=4)
gb_cv.fit(x_train,y_train)
print("Best Parameters:" ,gb_cv.best_params_)
print("Train Score:" ,gb_cv.best_score_)
print("Test score:" ,gb_cv.best_params_)
print("Gradient Forest cv classification Score",gb_cv.score(x_test,y_test))
method_names.append("Gradient Forest CV")
method_scores.append(gb_cv.score(x_test,y_test))

y_pred=gb_cv.predict(x_test)
conf_mat=confusion_matrix(y_test,y_pred)


f,ax=plt.subplots(figsize=(5,5))
sns.heatmap(conf_mat,annot=True,linewidth=0.5,linecolor="red",fmt=".0f",ax=ax)
plt.xlabel("Predicted values")
plt.ylabel("True values")
plt.show()
# Out:
# Best Parameters: {'learning_rate': 0.1, 'n_estimators': 400}
# Train Score: 0.9802689610836186
# Test score: {'learning_rate': 0.1, 'n_estimators': 400}
# Gradient Forest cv classification Score 0.9826498422712934

# %%
from sklearn.ensemble import AdaBoostClassifier
clf=AdaBoostClassifier(n_estimators=100,random_state=0)


clf.fit(x_train,y_train)
print("Ada Boost  classification Score",clf.score(x_test,y_test))
method_names.append("Ada boost")
method_scores.append(clf.score(x_test,y_test))

y_pred=clf.predict(x_test)
conf_mat=confusion_matrix(y_test,y_pred)


f,ax=plt.subplots(figsize=(5,5))
sns.heatmap(conf_mat,annot=True,linewidth=0.5,linecolor="red",fmt=".0f",ax=ax)
plt.xlabel("Predicted values")
plt.ylabel("True values")
plt.show()
# Out:
# Ada Boost  classification Score 0.9826498422712934

# %%
import xgboost as xgb
lr=0.01


xgb_classifier=xgb.XGBClassifier(eta=lr)
xgb_classifier.fit(x_train,y_train)
print("XGB Boost  classification Score",xgb_classifier.score(x_test,y_test))
method_names.append("XGB boost")
method_scores.append(xgb_classifier.score(x_test,y_test))

y_pred=xgb_classifier.predict(x_test)
conf_mat=confusion_matrix(y_test,y_pred)


f,ax=plt.subplots(figsize=(5,5))
sns.heatmap(conf_mat,annot=True,linewidth=0.5,linecolor="red",fmt=".0f",ax=ax)
plt.xlabel("Predicted values")
plt.ylabel("True values")
plt.show()
# Out:
# XGB Boost  classification Score 0.9684542586750788

# %%
from sklearn.ensemble import ExtraTreesClassifier
clf=ExtraTreesClassifier(n_estimators=100,random_state=0)


clf.fit(x_train,y_train)
print("ExtraTreesClassifier",clf.score(x_test,y_test))
method_names.append("ExtraTreesClassifier")
method_scores.append(clf.score(x_test,y_test))

y_pred=clf.predict(x_test)
conf_mat=confusion_matrix(y_test,y_pred)


f,ax=plt.subplots(figsize=(5,5))
sns.heatmap(conf_mat,annot=True,linewidth=0.5,linecolor="red",fmt=".0f",ax=ax)
plt.xlabel("Predicted values")
plt.ylabel("True values")
plt.show()
# Out:
# ExtraTreesClassifier 0.9842271293375394

# %%
import lightgbm as lgb
clf=lgb.LGBMClassifier()


clf.fit(x_train,y_train)
print("LGBMClassifier",clf.score(x_test,y_test))
method_names.append("LGBMClassifier")
method_scores.append(clf.score(x_test,y_test))

y_pred=clf.predict(x_test)
conf_mat=confusion_matrix(y_test,y_pred)


f,ax=plt.subplots(figsize=(5,5))
sns.heatmap(conf_mat,annot=True,linewidth=0.5,linecolor="red",fmt=".0f",ax=ax)
plt.xlabel("Predicted values")
plt.ylabel("True values")
plt.show()
# Out:
# LGBMClassifier 0.9810725552050473

# %%
from catboost import CatBoostClassifier
clf=CatBoostClassifier(iterations=5,learning_rate=0.1,loss_function='CrossEntropy')


clf.fit(x_train,y_train)
print("CatBoostClassifier",clf.score(x_test,y_test))
method_names.append("CatBoostClassifier")
method_scores.append(clf.score(x_test,y_test))

y_pred=clf.predict(x_test)
conf_mat=confusion_matrix(y_test,y_pred)


f,ax=plt.subplots(figsize=(5,5))
sns.heatmap(conf_mat,annot=True,linewidth=0.5,linecolor="red",fmt=".0f",ax=ax)
plt.xlabel("Predicted values")
plt.ylabel("True values")
plt.show()
# Out:
# 0:	learn: 0.5182488	total: 60ms	remaining: 240ms
# 1:	learn: 0.3890967	total: 64.7ms	remaining: 97ms
# 2:	learn: 0.3043929	total: 68.7ms	remaining: 45.8ms
# 3:	learn: 0.2445027	total: 72.9ms	remaining: 18.2ms
# 4:	learn: 0.1989563	total: 76.8ms	remaining: 0us
# CatBoostClassifier 0.9763406940063092

# %%
plt.figure(figsize=(15,10))
plt.ylim([0.85,1])
plt.bar(method_names,method_scores,width=0.5)
plt.xlabel('Method Name')
plt.ylabel('Method Score')
# Out:
# Text(0, 0.5, 'Method Score')
